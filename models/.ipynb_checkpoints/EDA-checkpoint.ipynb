# %%
import pandas as pd

# %%
df = pd.read_csv('image_emotions4.csv')
df
# Out:
#              filename  angry  sad  happy  fear  surprise  disgust  neutral  \
# 0     image_06637.jpg      1    0      0     0         0        0        0
# 1     image_06638.jpg      1    0      0     0         0        0        0
# 2     image_06639.jpg      0    0      0     0         0        1        0
# 3     image_06641.jpg      0    0      0     0         0        0        1
# 4     image_06642.jpg      0    1      0     0         0        0        0
# ...               ...    ...  ...    ...   ...       ...      ...      ...
# 5831  image_08036.jpg      1    0      0     0         0        0        0
# 5832  image_08035.jpg      0    0      0     0         0        0        1
# 5833  image_08038.jpg      0    1      0     0         0        0        0
# 5834  image_08028.jpg      0    0      0     1         0        0        0
# 5835  image_08026.jpg      1    0      0     0         0        0        0
#
#       emotion
# 0       angry
# 1       angry
# 2     disgust
# ...

# %%
df[['angry', 'sad', 'happy', 'neutral']].sum(axis=0)
# Out:
# angry       696
# sad        1415
# happy       257
# neutral    1231
# dtype: int64
