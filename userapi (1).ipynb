# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tqdm
# Out:
# ...
#
# ...

# %%
import numpy as np 
import pandas as pd 
import requests
import json
import tqdm

# %% [markdown]
# ## USER API

# %% [markdown]
# URLS

# %%
objects = []
url = ['https://www.rijksmuseum.nl/api/nl/usersets/212877-portretten?key=bC50tezr&format=json&pageSize=100', 'https://www.rijksmuseum.nl/api/nl/usersets/2116275-portretten?key=bC50tezr&format=json&pageSize=100','https://www.rijksmuseum.nl/api/nl/usersets/40970-portretten?key=bC50tezr&format=json&pageSize=100', 'https://www.rijksmuseum.nl/api/nl/usersets/105666-portretten?key=bC50tezr&format=json&pageSize=100', 'https://www.rijksmuseum.nl/api/nl/usersets/181266-portretten?key=bC50tezr&format=json&pageSize=100' , 'https://www.rijksmuseum.nl/api/nl/usersets/12643-portretten?key=bC50tezr&format=json&pageSize=100', 'https://www.rijksmuseum.nl/api/nl/usersets/1692024-portret?key=bC50tezr&format=json&pageSize=100', 'https://www.rijksmuseum.nl/api/nl/usersets/40230-portretten?key=bC50tezr&format=json&pageSize=100']

# %%
len(url)
# Out:
# 8

# %%
#for i in range(1):
  #url = 'https://www.rijksmuseum.nl/api/nl/usersets/212877-portretten?key=bC50tezr&format=json&pageSize=100p={i}' 
  #print(url)
  #r2 = requests.get(url)
  #members_data = r2.json()
  #print(json.dumps(members_data, indent=2))
  #objects.append(image_metadata)
# Out:
# https://www.rijksmuseum.nl/api/nl/usersets/212877-portretten?key=bC50tezr&format=json&pageSize=100p={i}
# {
#   "elapsedMilliseconds": 98,
#   "userSet": {
#     "links": {
#       "overview": "https://www.rijksmuseum.nl/api/usersets",
#       "web": "https://www.rijksmuseum.nl/nl/mijn/verzamelingen/212877--in60seconds/portretten"
#     },
#     "id": "212877-portretten",
#     "count": 89,
#     "type": "Default",
#     "name": "Portretten",
#     "slug": "portretten",
#     "description": null,
#     "user": {
#       "id": 212877,
#       "name": "in60seconds",
#       "lang": "nl",
#       "avatarUrl": null,
#       "headerUrl": null,
#       "initials": "I"
#     },
#     "setItems": [
#       {
#         "links": {
#           "artobject": "https://www.rijksmuseum.nl/api/nl/collection/SK-C-180",
#           "web": "https://www.rijksmuseum.nl/nl/collection/SK-C-180"
#         },
#         "id": "9e4d0996-912a-40d9-a228-3b8319e60600",
#         "objectNumber": "SK-C-180",
# ...

# %%
for i in range(len(url)):
  print(url[i])
  r2 = requests.get(url[i])
  members_data = r2.json()
  print(json.dumps(members_data, indent=2))
  objects.append(members_data)
# Out:
# https://www.rijksmuseum.nl/api/nl/usersets/212877-portretten?key=bC50tezr&format=json&pageSize=100
# {
#   "elapsedMilliseconds": 189,
#   "userSet": {
#     "links": {
#       "overview": "https://www.rijksmuseum.nl/api/usersets",
#       "web": "https://www.rijksmuseum.nl/nl/mijn/verzamelingen/212877--in60seconds/portretten"
#     },
#     "id": "212877-portretten",
#     "count": 89,
#     "type": "Default",
#     "name": "Portretten",
#     "slug": "portretten",
#     "description": null,
#     "user": {
#       "id": 212877,
#       "name": "in60seconds",
#       "lang": "nl",
#       "avatarUrl": null,
#       "headerUrl": null,
#       "initials": "I"
#     },
#     "setItems": [
#       {
#         "links": {
#           "artobject": "https://www.rijksmuseum.nl/api/nl/collection/SK-C-180",
#           "web": "https://www.rijksmuseum.nl/nl/collection/SK-C-180"
#         },
#         "id": "9e4d0996-912a-40d9-a228-3b8319e60600",
#         "objectNumber": "SK-C-180",
# ...

# %%
objects
# Out:
# [{'elapsedMilliseconds': 189,
#   'userSet': {'links': {'overview': 'https://www.rijksmuseum.nl/api/usersets',
#     'web': 'https://www.rijksmuseum.nl/nl/mijn/verzamelingen/212877--in60seconds/portretten'},
#    'id': '212877-portretten',
#    'count': 89,
#    'type': 'Default',
#    'name': 'Portretten',
#    'slug': 'portretten',
#    'description': None,
#    'user': {'id': 212877,
#     'name': 'in60seconds',
#     'lang': 'nl',
#     'avatarUrl': None,
#     'headerUrl': None,
#     'initials': 'I'},
#    'setItems': [{'links': {'artobject': 'https://www.rijksmuseum.nl/api/nl/collection/SK-C-180',
#       'web': 'https://www.rijksmuseum.nl/nl/collection/SK-C-180'},
#      'id': '9e4d0996-912a-40d9-a228-3b8319e60600',
#      'objectNumber': 'SK-C-180',
#      'relation': None,
#      'relationDescription': None,
#      'cropped': False,
#      'cropX': 0,
#      'cropY': 0,
#      'cropWidth': 0,
#      'cropHeight': 0,
#      'origWidth': 0,
#      'origHeight': 0,
# ...

# %%
image_objects = list(map(lambda x: x['userSet']['setItems'], objects))
image_urls = []
for image_obj in image_objects:
  urls = list(map(lambda x: x['image']['cdnUrl'], image_obj))
  image_urls += urls
print(image_urls)
print(len(image_urls))
# Out:
# ['https://lh4.ggpht.com/RcottnlLRe9AZBQe8H1U-_2sbesuVL5lksBhPszE47-eLrIzrbX5cUNzhsVlDDbIYiqL2jR0wWx82FKQA5YN50h_tlw=s0', 'https://lh6.ggpht.com/pqGMDTGItXibp-MP-6zal2LLDnU18oReJZ901p3ztOL05_Xx7kOoCOHyuakrdqMLAiuZUJYZ62nHGWzKL1WhvtC4lic=s0', 'https://lh3.ggpht.com/105f-f-8mvCLDIqCDPVB1UAFy6SPUNrfGM5eLFS5S-7pamvNb-Ls-obN7ApNIj6BAtzqDjiH2XyZjjyTNMlxWW1kztfi=s0', 'https://lh5.ggpht.com/uQ-NmKX5ucGkYMpJM8EWZQw85ikQAepousFA5_6amDauoV20j8JJsTpmc9tl0huXJUNxL1Pro5tMB3f8s3pe8b1f0Ws=s0', 'https://lh5.ggpht.com/PM-l8Vz4-aDMDVTJzBPFgGBR7xTzSZClx-p74BkV3ZmjZJPEVtBb8OXEyeZPrs2b9m1DsytPSnHXnmLUs5aofjO36w=s0', 'https://lh6.ggpht.com/vvJgnQCJreT7IFNAK8yqelFJ4HCpqbojsa7omy6SfA8OjeL1kMM-5NKYilfYX05QmYPTcnHQo_Caia6PqQutk-nMTg=s0', 'https://lh4.ggpht.com/yS4V6tsftGBPSi12IeT7BaxdHZKTlEWhFov5LtH0Rj75pRwsJEkKM3RYimYkDxp61j8WF3paksyUlLYwKAuBSG_3Qa0=s0', 'https://lh5.ggpht.com/Ybr7uzRmwH8gHKmuyT_dr7Md_Nuarwq0Ps5kUSns1DQT7gxtkQiyc_1DDLVgvXiT-q_NyyIE6FfsnxA8vIunjEY56QbE=s0', 'https://lh5.ggpht.com/R2acBpgNSGsLRe
# ...

# %%
import requests
from PIL import Image

for i in range(0, len(image_urls)):
    image = Image.open(requests.get(image_urls[i], stream = True).raw)
    image.save('images/img_%d.jpg' % (i + 1))

# %%
#url = f'https://www.rijksmuseum.nl/api/nl/usersets/2116275-portretten?key=bC50tezr&format=json&pageSize=100' 
#print(url)

# %%
#url = f'https://www.rijksmuseum.nl/api/nl/usersets/40970-portretten?key=bC50tezr&format=json&pageSize=100' 
#print(url)

# %%
#url = f'https://www.rijksmuseum.nl/api/nl/usersets/105666-portretten?key=bC50tezr&format=json&pageSize=100' 
#print(url)

# %%
#url = f'https://www.rijksmuseum.nl/api/nl/usersets/181266-portretten?key=bC50tezr&format=json&pageSize=100' 
#print(url)

# %%
#url = f'https://www.rijksmuseum.nl/api/nl/usersets/12643-portretten?key=bC50tezr&format=json&pageSize=100' 
#print(url)

# %%
#url = f'https://www.rijksmuseum.nl/api/nl/usersets/1692024-portret?key=bC50tezr&format=json&pageSize=100' 
#print(url)

# %%
#url = f'https://www.rijksmuseum.nl/api/nl/usersets/40230-portretten?key=bC50tezr&format=json&pageSize=100' 
print(url)
